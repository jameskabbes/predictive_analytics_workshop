# %% [markdown]
# # 1. Finding Slope and Intercept of a Line

# %%
import matplotlib.pyplot as plt
import config
import pandas as pd

# %%
df = pd.read_csv(config.DATA_DIR / "data_01.csv")

# %%
plt.scatter(df["x"], df["y"])
