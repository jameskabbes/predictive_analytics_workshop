# %% [markdown]
# # Electric Load Prediction

# %% [markdown]
# Goal: predict the electric load on the grid at a certain time of the day, using availble information like weather, date and time, etc.
#
# Keep in mind: residential and commercial load is cyclical. What frequencies are present in this dataset? How can you use that to your advantage?
#
# Read more about the data [here](https://www.kaggle.com/datasets/ziya07/hourly-power-load-and-climate-data)

# %%
import pandas as pd

# %%
df = pd.read_csv('power_load_dataset.csv')
